# %%
import matplotlib.pyplot as plt
import seaborn as sn
import pandas as pd

x=[0.895, 0.91,0.926, 0.929,0.931]
plt.plot(x)
plt.show()

# %%
years=[2010, 2011, 2012, 2014]
x=[0.895, 0.91,0.926, 0.929]
plt.plot(years, x)
plt.plot(years, x)
plt.xlabel('Year')
plt.ylabel('Yieald (tons per hectare)')

#years= range(2000,2014)
apples=[0.895, 0.919, 0.929, 0.931]
orange=[0.962, 0.941, 0.930, 0.918]
plt.plot(years, apples)
plt.plot(years,orange)
plt.xlabel('Year')
plt.ylabel('Yieald (tons per hectare)');
